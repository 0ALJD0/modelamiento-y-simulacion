# %% [markdown]
# fuentes:
#
# datos:https://www.ecuadorencifras.gob.ec/estadisticas-laborales-marzo-2022/
# datos2:https://www.ecuadorencifras.gob.ec/informacion-censal-cantonal/
# datos3:https://www.ecuadorencifras.gob.ec/vacunacion-covid-19/
# datos4:https://www.kaggle.com/datasets/dannyguevara/enemdu-mensual-ecuador?select=enemdu_consumidor_2019_03.sav
# Missing optional dependency 'pyreadstat'.  Use pip or conda to install pyreadstat. para el 4to

# %%
#importamos las librerías necesarias
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
datos =  pd.read_csv('./datosEmpleos2021/datosIndicadoresEmpleos.csv')  
datos
# Out:
#     Encuesta Periodo                          Indicadores         Total  \
# 0    ENEMDU*  ene-21                      Población Total  1.771562e+07
# 1    ENEMDU*  ene-21           Población menor de 15 años  5.127554e+06
# 2    ENEMDU*  ene-21  Población en Edad de Trabajar (PET)  1.258806e+07
# 3    ENEMDU*  ene-21      Población Económicamente Activa  8.346101e+06
# 4    ENEMDU*  ene-21                               Empleo  7.900929e+06
# ..       ...     ...                                  ...           ...
# 265  ENEMDU*  22-Mar                    Desempleo Abierto  3.544044e+05
# 266  ENEMDU*  22-Mar                     Desempleo Oculto  4.324087e+04
# 267  ENEMDU*  22-Mar                    Desempleo Cesante  3.152392e+05
# 268  ENEMDU*  22-Mar                      Desempleo Nuevo  8.240611e+04
# 269  ENEMDU*  22-Mar    Población Económicamente Inactiva  4.491099e+06
#
#            Urbana         Rural        Hombre         Mujer
# ...

# %%
datos2= pd.read_json('./datosCenso2010manabí/csvjson.json')
datos2
# Out:
#         Cantón                Parroquia Casa/Villa  \
# 0   24 DE MAYO  ARQ. SIXTO DURAN BALLEN        582
# 1   24 DE MAYO               BELLAVISTA        855
# 2   24 DE MAYO                    NOBOA        923
# 3   24 DE MAYO                    SUCRE      2,305
# 4      BOLIVAR                  CALCETA      6,077
# ..         ...                      ...        ...
# 69       SUCRE                CHARAPOTO      4,583
# 70       SUCRE               SAN ISIDRO      1,937
# 71     TOSAGUA        ANGEL PEDRO GILER      1,190
# 72     TOSAGUA               BACHILLERO        682
# 73     TOSAGUA                  TOSAGUA      4,264
#
#    Departamento en casa o edificio Cuarto(s) en casa de inquilinato Mediagua  \
# 0                                4                                2        1
# 1                                3                                4        7
# 2                                7                                0       10
# ...

# %%
datos3= pd.read_xml('./datosVacunacion2021/vacunacion2021xml.xml')
datos3
# Out:
#    Colors  WindowHeight  WindowWidth  WindowTopX  WindowTopY ProtectStructure  \
# 0     NaN           NaN          NaN         NaN         NaN             None
# 1     NaN        9000.0      13860.0       240.0        75.0            False
# 2     NaN           NaN          NaN         NaN         NaN             None
# 3     NaN           NaN          NaN         NaN         NaN             None
#
#   ProtectWindows  Style   Name  Table  WorksheetOptions
# 0           None    NaN   None    NaN               NaN
# 1          False    NaN   None    NaN               NaN
# 2           None    NaN   None    NaN               NaN
# 3           None    NaN  input    NaN               NaN

# %%
dato4 = pd.read_spss("./enemdu_consumidor_2019_03.sav")
dato4
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20300/1929172264.py in <module>
# ----> 1 dato4 = pd.read_spss("./enemdu_consumidor_2019_03.sav")
#       2 dato4
#
# ~\anaconda3\lib\site-packages\pandas\io\spss.py in read_spss(path, usecols, convert_categoricals)
#      36     DataFrame
#      37     """
# ---> 38     pyreadstat = import_optional_dependency("pyreadstat")
#      39
#      40     if usecols is not None:
#
# ~\anaconda3\lib\site-packages\pandas\compat\_optional.py in import_optional_dependency(name, extra, errors, min_version)
#     116     except ImportError:
#     117         if errors == "raise":
# --> 118             raise ImportError(msg) from None
#     119         else:
#     120             return None
#
# ImportError: Missing optional dependency 'pyreadstat'.  Use pip or conda to install pyreadstat.
